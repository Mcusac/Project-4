# %%
import pandas as pd

# %%
df = pd.read_csv('dataset1.csv')
df.head(20)
# Out:
#     Unnamed: 0  year           make  \
# 0            0  1993     Land Rover
# 1            1  1997      Chevrolet
# 2            2  1990        Porsche
# 3            3  2003         Toyota
# 4            4  1971        Triumph
# 5            5  1992     Volkswagen
# 6            6  2008         Toyota
# 7            7  1978      Chevrolet
# 8            8  2018          Dodge
# 9            9  1988  Mercedes-Benz
# 10          10  2001  Mercedes-Benz
# 11          11  1962        Triumph
# 12          12  2002        Pontiac
# 13          13  1972           Ford
# 14          14  1970           Ford
# 15          15  2008          Honda
# 16          16  2008        Porsche
# 17          17  1975        Triumph
# 18          18  1995        Porsche
# 19          19  1978      Chevrolet
#
#                                         model final_price  mileage  \
# 0   Land Rover 110 / Defender 110 (Euro Spec)     $59,500        0
# ...

# %%
df = df.query('mileage != 0')
df.head(20)
# Out:
#     Unnamed: 0  year           make                             model  \
# 1            1  1997      Chevrolet                Chevrolet Suburban
# 2            2  1990        Porsche                   Porsche 964 911
# 3            3  2003         Toyota                     Toyota Pickup
# 5            5  1992     Volkswagen  Volkswagen Golf/Rabbit Cabriolet
# 6            6  2008         Toyota                 Toyota FJ Cruiser
# 7            7  1978      Chevrolet                  Chevrolet Pickup
# 8            8  2018          Dodge                  Dodge Challenger
# 10          10  2001  Mercedes-Benz             Mercedes-Benz R129 SL
# 11          11  1962        Triumph                       Triumph TR4
# 12          12  2002        Pontiac                  Pontiac Firebird
# 13          13  1972           Ford                               NaN
# 15          15  2008          Honda                       Honda S2000
# ...

# %%
df.drop_duplicates()
df
# Out:
#       Unnamed: 0  year        make                             model  \
# 1              1  1997   Chevrolet                Chevrolet Suburban
# 2              2  1990     Porsche                   Porsche 964 911
# 3              3  2003      Toyota                     Toyota Pickup
# 5              5  1992  Volkswagen  Volkswagen Golf/Rabbit Cabriolet
# 6              6  2008      Toyota                 Toyota FJ Cruiser
# ...          ...   ...         ...                               ...
# 9963        9963  1983        Jeep                         Jeep CJ-7
# 9964        9964  1997        Ford           Ford F-Series 1992-1997
# 9965        9965  1972       Honda                 Honda Motorcycles
# 9966        9966  2005        Ford                  Ford Thunderbird
# 9967        9967  1974  Volkswagen                 Volkswagen Beetle
#
#      final_price  mileage                                 engine  zipcode
# ...

# %%
df = df.dropna()
df
# Out:
#       Unnamed: 0  year        make                             model  \
# 1              1  1997   Chevrolet                Chevrolet Suburban
# 2              2  1990     Porsche                   Porsche 964 911
# 3              3  2003      Toyota                     Toyota Pickup
# 5              5  1992  Volkswagen  Volkswagen Golf/Rabbit Cabriolet
# 6              6  2008      Toyota                 Toyota FJ Cruiser
# ...          ...   ...         ...                               ...
# 9963        9963  1983        Jeep                         Jeep CJ-7
# 9964        9964  1997        Ford           Ford F-Series 1992-1997
# 9965        9965  1972       Honda                 Honda Motorcycles
# 9966        9966  2005        Ford                  Ford Thunderbird
# 9967        9967  1974  Volkswagen                 Volkswagen Beetle
#
#      final_price  mileage                                 engine  zipcode
# ...

# %%
df['engine string'] = df['engine']
# Out:
# C:\Users\austi\AppData\Local\Temp/ipykernel_10424/308805021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['engine string'] = df['engine']

# %%
for i in range(7604):
    string = df.iloc[i, 6]
    string = string.replace('-', ' ')
    string = string.replace('cc', ' cc')
    string = string.replace('ci', ' ci')
    string = string.replace('L', ' L')
    string = string.replace(',', '')
    string = string.replace('.', '.')
    df.iloc[i,6] = string
df
# Out:
# C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#       Unnamed: 0  year        make                             model  \
# 1              1  1997   Chevrolet                Chevrolet Suburban
# 2              2  1990     Porsche                   Porsche 964 911
# 3              3  2003      Toyota                     Toyota Pickup
# 5              5  1992  Volkswagen  Volkswagen Golf/Rabbit Cabriolet
# 6              6  2008      Toyota                 Toyota FJ Cruiser
# ...          ...   ...         ...                               ...
# ...

# %%
for i in range(7604):
    string = df.iloc[i, 6]
    try:
        aList = string.split()
        li = 0
        for j in aList:
            try:
                j = float(j)
            except:
                pass
            if type(j) == float:
                try:
                    if aList[li + 1].lower() == 'liter':
                        df.iloc[i, 6] = j * 1000
                    elif aList[li + 1].lower() == 'l':
                        df.iloc[i,6] = j * 1000
                    elif aList[li + 1].lower() == 'cc':
                        df.iloc[i,6] = j
                    elif aList[li + 1].lower() == 'ci':
                        df.iloc[i,6] = j * 16.387
                except:
                    df.iloc[i,6] = 0
            li = li + 1
    except:
        pass
# Out:
# C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.head(20)
# Out:
#     Unnamed: 0  year           make                             model  \
# 1            1  1997      Chevrolet                Chevrolet Suburban
# 2            2  1990        Porsche                   Porsche 964 911
# 3            3  2003         Toyota                     Toyota Pickup
# 5            5  1992     Volkswagen  Volkswagen Golf/Rabbit Cabriolet
# 6            6  2008         Toyota                 Toyota FJ Cruiser
# 7            7  1978      Chevrolet                  Chevrolet Pickup
# 8            8  2018          Dodge                  Dodge Challenger
# 10          10  2001  Mercedes-Benz             Mercedes-Benz R129 SL
# 11          11  1962        Triumph                       Triumph TR4
# 12          12  2002        Pontiac                  Pontiac Firebird
# 15          15  2008          Honda                       Honda S2000
# 17          17  1975        Triumph               Triumph Motorcycles
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# year              int64
# make             object
# model            object
# final_price      object
# mileage           int64
# engine           object
# zipcode           int64
# engine string    object
# dtype: object

# %%
for i in range(7604):
    value = df.iloc[i, 6]
    if type(value) == str:
        df.iloc[i, 6] = 0
# Out:
# C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['engine'] = df['engine'].astype(float)
# Out:
# C:\Users\austi\AppData\Local\Temp/ipykernel_10424/2176177890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['engine'] = df['engine'].astype(float)

# %%
df = df.query('engine != 0')
df
# Out:
#       Unnamed: 0  year        make                             model  \
# 1              1  1997   Chevrolet                Chevrolet Suburban
# 2              2  1990     Porsche                   Porsche 964 911
# 3              3  2003      Toyota                     Toyota Pickup
# 5              5  1992  Volkswagen  Volkswagen Golf/Rabbit Cabriolet
# 6              6  2008      Toyota                 Toyota FJ Cruiser
# ...          ...   ...         ...                               ...
# 9963        9963  1983        Jeep                         Jeep CJ-7
# 9964        9964  1997        Ford           Ford F-Series 1992-1997
# 9965        9965  1972       Honda                 Honda Motorcycles
# 9966        9966  2005        Ford                  Ford Thunderbird
# 9967        9967  1974  Volkswagen                 Volkswagen Beetle
#
#      final_price  mileage  engine  zipcode  \
# 1        $17,000    67000  5700.0    60069
# 2       $225,000     1000  3800.0    84790
# ...

# %%
df = df.query('mileage < 300000')
df
# Out:
#       Unnamed: 0  year        make                             model  \
# 1              1  1997   Chevrolet                Chevrolet Suburban
# 2              2  1990     Porsche                   Porsche 964 911
# 3              3  2003      Toyota                     Toyota Pickup
# 5              5  1992  Volkswagen  Volkswagen Golf/Rabbit Cabriolet
# 6              6  2008      Toyota                 Toyota FJ Cruiser
# ...          ...   ...         ...                               ...
# 9963        9963  1983        Jeep                         Jeep CJ-7
# 9964        9964  1997        Ford           Ford F-Series 1992-1997
# 9965        9965  1972       Honda                 Honda Motorcycles
# 9966        9966  2005        Ford                  Ford Thunderbird
# 9967        9967  1974  Volkswagen                 Volkswagen Beetle
#
#      final_price  mileage  engine  zipcode  \
# 1        $17,000    67000  5700.0    60069
# 2       $225,000     1000  3800.0    84790
# ...

# %%
df['final_price']=(df['final_price'].replace( '[\$,)]','', regex=True )
               .replace( '[(]','-',   regex=True ).astype(float))
# Out:
# C:\Users\austi\AppData\Local\Temp/ipykernel_10424/3087032467.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['final_price']=(df['final_price'].replace( '[\$,)]','', regex=True )

# %%
df['final_price'].sort_values().head(100)
# Out:
# 6937       0.0
# 6237       0.0
# 9731       0.0
# 3924       0.0
# 3732       0.0
#          ...
# 9817    5150.0
# 1626    5200.0
# 8693    5200.0
# 876     5200.0
# 9553    5200.0
# Name: final_price, Length: 100, dtype: float64

# %%
df = df.query('price < 500000')
df = df.query('price > 5000')
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     199             if self.has_resolvers:
# --> 200                 return self.resolvers[key]
#     201
#
# ~\anaconda3\envs\PythonData\lib\collections\__init__.py in __getitem__(self, key)
#     897                 pass
# --> 898         return self.__missing__(key)            # support subclasses that define __missing__
#     899
#
# ~\anaconda3\envs\PythonData\lib\collections\__init__.py in __missing__(self, key)
#     889     def __missing__(self, key):
# --> 890         raise KeyError(key)
#     891
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.to_csv('final_final_dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10424/316360416.py in <module>
# ----> 1 df.to_csv('final_final_dataset.csv')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ...

# %%
import sqlite3
conn = sqlite3.connect('data.sqlite')
df.to_sql('new_table_name', conn, if_exists='replace', index=False)
# Out:
# C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(
