# %%
import pandas as pd

# %%
df = pd.read_csv('dataset1.csv')
df.head(20)
# Out:
#     Unnamed: 0  year           make                          model  \
# 0            0  1999        Porsche                Porsche 996 911
# 1            1  1976        Triumph                    Triumph TR6
# 2            2  2015      Chevrolet          Chevrolet Corvette C7
# 3            3  2022        Porsche                Porsche 911 GT3
# 4            4  2005  Mercedes-Benz                            NaN
# 5            5  1994            BMW               BMW E31 8-Series
# 6            6  2020           Jeep                  Jeep Wrangler
# 7            7  1966           Ford       Ford Mustang 1964.5-1966
# 8            8  1980  Mercedes-Benz             Mercedes-Benz W123
# 9            9  2005          Lotus                    Lotus Elise
# 10          10  2015         Jaguar                  Jaguar F-Type
# 11          11  1946          Dodge                            NaN
# 12          12  1962      Chevrolet              Chevrolet Corvair
# 13          13  1928      Chevrolet                            NaN
# 14          14  1973          Honda              Honda Motorcycles
# 15          15  2003      Chevrolet               Chevrolet Pickup
# 16          16  2001           Audi                        Audi A4
# 17          17  2001  Mercedes-Benz          Mercedes-Benz R129 SL
# 18          18  2004  Mercedes-Benz          Mercedes-Benz R230 SL
# 19          19  1995         Toyota  Toyota Land Cruiser 80-Series
#
#    final_price  mileage                              engine  zipcode  \
# 0      $29,840    44000                  3.4-Liter Flat-Six    33407
# 1      $23,500    95000                2.5-Liter Inline-Six    46229
# 2      $87,000   410000           Supercharged 6.2-Liter V8    45429
# 3     $245,000        0                  4.0-Liter Flat-Six    98052
# 4      $16,000    32000  Supercharged 1.8-Liter Inline-Four    34771
# 5      $19,900    95000                        4.0-Liter V8    92887
# 6      $65,000    17000                        6.4-Liter V8    48507
# 7      $35,750    31000                            289ci V8    97005
# 8      $13,750    58000                2.8-Liter Inline-Six    48067
# 9      $46,000    16000               1.8-Liter Inline-Four    78520
# 10     $46,500    52000           Supercharged 5.0-Liter V8    53217
# 11     $12,000    88000                 230ci Straight-Six     59079
# 12      $7,862    63000                  2.3-Liter Flat-Six    37416
# 13      $5,100    26000                   171ci Inline-Four    21713
# 14      $4,500        0       Replacement 544cc Inline-Four    92505
# 15     $23,000    64000                    5.3-Liter LS3 V8    20111
# 16     $10,028    46000                        2.8-Liter V6    95131
# 17     $13,100    76000                        5.0-Liter V8    33180
# 18     $25,500    43000                        5.0-Liter V8    92648
# 19     $35,000   195000              4.5L 1FZ-FE Inline-Six    32812
#
#                         car_fax_report
# 0                Recent Service Record
# 1                      Service Manuals
# 2          Accident-Free Carfax Report
# 3                  Clean Carfax Report
# 4                  Clean Carfax Report
# 5                  Clean Carfax Report
# 6          Accident-Free Carfax Report
# 7              Pioneer AM/FM/CD Stereo
# 8                          Spare Parts
# 9                  Clean Carfax Report
# 10                 Clean Carfax Report
# 11              AM/FM CD Stereo System
# 12                                 Bed
# 13             Rear-Mounted Spare Tire
# 14  Custom-Fabricated 4-Into-4 Exhaust
# 15                 Clean Carfax Report
# 16                      Window Sticker
# 17                       Hardtop Stand
# 18                 Clean Carfax Report
# 19                       Carfax Report

# %%
df = df.query('mileage != 0')
df.head(20)
# Out:
#     Unnamed: 0  year           make                          model  \
# 0            0  1999        Porsche                Porsche 996 911
# 1            1  1976        Triumph                    Triumph TR6
# 2            2  2015      Chevrolet          Chevrolet Corvette C7
# 4            4  2005  Mercedes-Benz                            NaN
# 5            5  1994            BMW               BMW E31 8-Series
# 6            6  2020           Jeep                  Jeep Wrangler
# 7            7  1966           Ford       Ford Mustang 1964.5-1966
# 8            8  1980  Mercedes-Benz             Mercedes-Benz W123
# 9            9  2005          Lotus                    Lotus Elise
# 10          10  2015         Jaguar                  Jaguar F-Type
# 11          11  1946          Dodge                            NaN
# 12          12  1962      Chevrolet              Chevrolet Corvair
# 13          13  1928      Chevrolet                            NaN
# 15          15  2003      Chevrolet               Chevrolet Pickup
# 16          16  2001           Audi                        Audi A4
# 17          17  2001  Mercedes-Benz          Mercedes-Benz R129 SL
# 18          18  2004  Mercedes-Benz          Mercedes-Benz R230 SL
# 19          19  1995         Toyota  Toyota Land Cruiser 80-Series
# 20          20  1996           Ford        Ford F-Series 1992-1997
# 21          21  1966           Ford               Ford Thunderbird
#
#    final_price  mileage                              engine  zipcode  \
# 0      $29,840    44000                  3.4-Liter Flat-Six    33407
# 1      $23,500    95000                2.5-Liter Inline-Six    46229
# 2      $87,000   410000           Supercharged 6.2-Liter V8    45429
# 4      $16,000    32000  Supercharged 1.8-Liter Inline-Four    34771
# 5      $19,900    95000                        4.0-Liter V8    92887
# 6      $65,000    17000                        6.4-Liter V8    48507
# 7      $35,750    31000                            289ci V8    97005
# 8      $13,750    58000                2.8-Liter Inline-Six    48067
# 9      $46,000    16000               1.8-Liter Inline-Four    78520
# 10     $46,500    52000           Supercharged 5.0-Liter V8    53217
# 11     $12,000    88000                 230ci Straight-Six     59079
# 12      $7,862    63000                  2.3-Liter Flat-Six    37416
# 13      $5,100    26000                   171ci Inline-Four    21713
# 15     $23,000    64000                    5.3-Liter LS3 V8    20111
# 16     $10,028    46000                        2.8-Liter V6    95131
# 17     $13,100    76000                        5.0-Liter V8    33180
# 18     $25,500    43000                        5.0-Liter V8    92648
# 19     $35,000   195000              4.5L 1FZ-FE Inline-Six    32812
# 20     $21,050    74000                    7.5-Liter EFI V8    87120
# 21     $28,250    67000                            390ci V8    90740
#
#                  car_fax_report
# 0         Recent Service Record
# 1               Service Manuals
# 2   Accident-Free Carfax Report
# 4           Clean Carfax Report
# 5           Clean Carfax Report
# 6   Accident-Free Carfax Report
# 7       Pioneer AM/FM/CD Stereo
# 8                   Spare Parts
# 9           Clean Carfax Report
# 10          Clean Carfax Report
# 11       AM/FM CD Stereo System
# 12                          Bed
# 13      Rear-Mounted Spare Tire
# 15          Clean Carfax Report
# 16               Window Sticker
# 17                Hardtop Stand
# 18          Clean Carfax Report
# 19                Carfax Report
# 20         Clean Carfax Report
# 21     Thunderbird Wheel Covers

# %%
df.drop_duplicates()
df
# Out:
#       Unnamed: 0  year           make                              model  \
# 0              0  1999        Porsche                    Porsche 996 911
# 1              1  1976        Triumph                        Triumph TR6
# 2              2  2015      Chevrolet              Chevrolet Corvette C7
# 4              4  2005  Mercedes-Benz                                NaN
# 5              5  1994            BMW                   BMW E31 8-Series
# ...          ...   ...            ...                                ...
# 9978        9978  1968           Ford  Ford Bronco U13/U14/U15 1966-1977
# 9979        9979  1973            BMW                        BMW 2002tii
# 9980        9980  1990        Porsche                    Porsche 964 911
# 9981        9981  1966        Pontiac                        Pontiac GTO
# 9982        9982  2020           Ford                  Ford Mustang S550
#
#      final_price  mileage                              engine  zipcode  \
# 0        $29,840    44000                  3.4-Liter Flat-Six    33407
# 1        $23,500    95000                2.5-Liter Inline-Six    46229
# 2        $87,000   410000           Supercharged 6.2-Liter V8    45429
# 4        $16,000    32000  Supercharged 1.8-Liter Inline-Four    34771
# 5        $19,900    95000                        4.0-Liter V8    92887
# ...          ...      ...                                 ...      ...
# 9978     $44,000    83000             Fuel-Injected 302ci V8     85003
# 9979     $49,250    30000   Numbers-Matching 2.0L Inline-Four    53532
# 9980     $93,500    78000      Replacement 3.6-Liter Flat-Six    78738
# 9981    $110,000    68000                Replacement 389ci V8    78628
# 9982    $154,000   406000                 5.2-Liter Voodoo V8    87043
#
#                          car_fax_report
# 0                 Recent Service Record
# 1                       Service Manuals
# 2           Accident-Free Carfax Report
# 4                   Clean Carfax Report
# 5                   Clean Carfax Report
# ...                                 ...
# 9978  15" Wheels w/33" BFGoodrich Tires
# 9979                          Tool Roll
# 9980                     Window Sticker
# 9981              Refurbishment Records
# 9982                Clean Carfax Report
#
# [8239 rows x 9 columns]

# %%
df = df.dropna()
df
# Out:
#       Unnamed: 0  year       make                              model  \
# 0              0  1999    Porsche                    Porsche 996 911
# 1              1  1976    Triumph                        Triumph TR6
# 2              2  2015  Chevrolet              Chevrolet Corvette C7
# 5              5  1994        BMW                   BMW E31 8-Series
# 6              6  2020       Jeep                      Jeep Wrangler
# ...          ...   ...        ...                                ...
# 9978        9978  1968       Ford  Ford Bronco U13/U14/U15 1966-1977
# 9979        9979  1973        BMW                        BMW 2002tii
# 9980        9980  1990    Porsche                    Porsche 964 911
# 9981        9981  1966    Pontiac                        Pontiac GTO
# 9982        9982  2020       Ford                  Ford Mustang S550
#
#      final_price  mileage                             engine  zipcode  \
# 0        $29,840    44000                 3.4-Liter Flat-Six    33407
# 1        $23,500    95000               2.5-Liter Inline-Six    46229
# 2        $87,000   410000          Supercharged 6.2-Liter V8    45429
# 5        $19,900    95000                       4.0-Liter V8    92887
# 6        $65,000    17000                       6.4-Liter V8    48507
# ...          ...      ...                                ...      ...
# 9978     $44,000    83000            Fuel-Injected 302ci V8     85003
# 9979     $49,250    30000  Numbers-Matching 2.0L Inline-Four    53532
# 9980     $93,500    78000     Replacement 3.6-Liter Flat-Six    78738
# 9981    $110,000    68000               Replacement 389ci V8    78628
# 9982    $154,000   406000                5.2-Liter Voodoo V8    87043
#
#                          car_fax_report
# 0                 Recent Service Record
# 1                       Service Manuals
# 2           Accident-Free Carfax Report
# 5                   Clean Carfax Report
# 6           Accident-Free Carfax Report
# ...                                 ...
# 9978  15" Wheels w/33" BFGoodrich Tires
# 9979                          Tool Roll
# 9980                     Window Sticker
# 9981              Refurbishment Records
# 9982                Clean Carfax Report
#
# [7624 rows x 9 columns]

# %%
for i in range(7624):
    string = df.iloc[i, 8]
    aList = string.split()
    for j in aList:
        if j.lower() == 'carfax':
            string = 'Carfax'
    if string != 'Carfax':
        string = 'No Carfax'
    df.iloc[i, 8] = string
# Out:
# C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['engine_string'] = df['engine']
# Out:
# C:\Users\austi\AppData\Local\Temp/ipykernel_15492/308805021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['engine string'] = df['engine']

# %%
for i in range(7624):
    string = df.iloc[i, 6]
    string = string.replace('-', ' ')
    string = string.replace('cc', ' cc')
    string = string.replace('ci', ' ci')
    string = string.replace('L', ' L')
    string = string.replace(',', '')
    string = string.replace('.', '.')
    df.iloc[i,6] = string
df
# Out:
#       Unnamed: 0  year       make                              model  \
# 0              0  1999    Porsche                    Porsche 996 911
# 1              1  1976    Triumph                        Triumph TR6
# 2              2  2015  Chevrolet              Chevrolet Corvette C7
# 5              5  1994        BMW                   BMW E31 8-Series
# 6              6  2020       Jeep                      Jeep Wrangler
# ...          ...   ...        ...                                ...
# 9978        9978  1968       Ford  Ford Bronco U13/U14/U15 1966-1977
# 9979        9979  1973        BMW                        BMW 2002tii
# 9980        9980  1990    Porsche                    Porsche 964 911
# 9981        9981  1966    Pontiac                        Pontiac GTO
# 9982        9982  2020       Ford                  Ford Mustang S550
#
#      final_price  mileage                              engine  zipcode  \
# 0        $29,840    44000                 3.4  Liter Flat Six    33407
# 1        $23,500    95000               2.5  Liter Inline Six    46229
# 2        $87,000   410000          Supercharged 6.2  Liter V8    45429
# 5        $19,900    95000                       4.0  Liter V8    92887
# 6        $65,000    17000                       6.4  Liter V8    48507
# ...          ...      ...                                 ...      ...
# 9978     $44,000    83000            Fuel Injected 302 ci V8     85003
# 9979     $49,250    30000  Numbers Matching 2.0 L Inline Four    53532
# 9980     $93,500    78000     Replacement 3.6  Liter Flat Six    78738
# 9981    $110,000    68000               Replacement 389 ci V8    78628
# 9982    $154,000   406000                5.2  Liter Voodoo V8    87043
#
#      car_fax_report                      engine string
# 0         No Carfax                 3.4-Liter Flat-Six
# 1         No Carfax               2.5-Liter Inline-Six
# 2            Carfax          Supercharged 6.2-Liter V8
# 5            Carfax                       4.0-Liter V8
# 6            Carfax                       6.4-Liter V8
# ...             ...                                ...
# 9978      No Carfax            Fuel-Injected 302ci V8
# 9979      No Carfax  Numbers-Matching 2.0L Inline-Four
# 9980      No Carfax     Replacement 3.6-Liter Flat-Six
# 9981      No Carfax               Replacement 389ci V8
# 9982         Carfax                5.2-Liter Voodoo V8
#
# [7624 rows x 10 columns]

# %%
for i in range(7604):
    string = df.iloc[i, 6]
    try:
        aList = string.split()
        li = 0
        for j in aList:
            try:
                j = float(j)
            except:
                pass
            if type(j) == float:
                try:
                    if aList[li + 1].lower() == 'liter':
                        df.iloc[i, 6] = j * 1000
                    elif aList[li + 1].lower() == 'l':
                        df.iloc[i,6] = j * 1000
                    elif aList[li + 1].lower() == 'cc':
                        df.iloc[i,6] = j
                    elif aList[li + 1].lower() == 'ci':
                        df.iloc[i,6] = j * 16.387
                except:
                    df.iloc[i,6] = 0
            li = li + 1
    except:
        pass
# Out:
# C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.head(20)
# Out:
#     Unnamed: 0  year           make                          model  \
# 0            0  1999        Porsche                Porsche 996 911
# 1            1  1976        Triumph                    Triumph TR6
# 2            2  2015      Chevrolet          Chevrolet Corvette C7
# 5            5  1994            BMW               BMW E31 8-Series
# 6            6  2020           Jeep                  Jeep Wrangler
# 7            7  1966           Ford       Ford Mustang 1964.5-1966
# 8            8  1980  Mercedes-Benz             Mercedes-Benz W123
# 9            9  2005          Lotus                    Lotus Elise
# 10          10  2015         Jaguar                  Jaguar F-Type
# 12          12  1962      Chevrolet              Chevrolet Corvair
# 15          15  2003      Chevrolet               Chevrolet Pickup
# 16          16  2001           Audi                        Audi A4
# 17          17  2001  Mercedes-Benz          Mercedes-Benz R129 SL
# 18          18  2004  Mercedes-Benz          Mercedes-Benz R230 SL
# 19          19  1995         Toyota  Toyota Land Cruiser 80-Series
# 20          20  1996           Ford        Ford F-Series 1992-1997
# 21          21  1966           Ford               Ford Thunderbird
# 23          23  2009  Mercedes-Benz     Mercedes-Benz W211 E-Class
# 24          24  1979        Porsche                  Porsche 911SC
# 25          25  1990         Nissan                   Nissan 300ZX
#
#    final_price  mileage    engine  zipcode car_fax_report  \
# 0      $29,840    44000    3400.0    33407      No Carfax
# 1      $23,500    95000    2500.0    46229      No Carfax
# 2      $87,000   410000    6200.0    45429         Carfax
# 5      $19,900    95000    4000.0    92887         Carfax
# 6      $65,000    17000    6400.0    48507         Carfax
# 7      $35,750    31000  4735.843    97005      No Carfax
# 8      $13,750    58000    2800.0    48067      No Carfax
# 9      $46,000    16000    1800.0    78520         Carfax
# 10     $46,500    52000    5000.0    53217         Carfax
# 12      $7,862    63000    2300.0    37416      No Carfax
# 15     $23,000    64000    5300.0    20111         Carfax
# 16     $10,028    46000    2800.0    95131      No Carfax
# 17     $13,100    76000    5000.0    33180      No Carfax
# 18     $25,500    43000    5000.0    92648         Carfax
# 19     $35,000   195000    4500.0    32812         Carfax
# 20     $21,050    74000    7500.0    87120         Carfax
# 21     $28,250    67000   6390.93    90740      No Carfax
# 23     $11,400    83000    3000.0    53114         Carfax
# 24     $85,000   135000    3000.0    97227      No Carfax
# 25     $35,250    49000    3000.0    92663         Carfax
#
#                      engine string
# 0               3.4-Liter Flat-Six
# 1             2.5-Liter Inline-Six
# 2        Supercharged 6.2-Liter V8
# 5                     4.0-Liter V8
# 6                     6.4-Liter V8
# 7                         289ci V8
# 8             2.8-Liter Inline-Six
# 9            1.8-Liter Inline-Four
# 10       Supercharged 5.0-Liter V8
# 12              2.3-Liter Flat-Six
# 15                5.3-Liter LS3 V8
# 16                    2.8-Liter V6
# 17                    5.0-Liter V8
# 18                    5.0-Liter V8
# 19          4.5L 1FZ-FE Inline-Six
# 20                7.5-Liter EFI V8
# 21                        390ci V8
# 23        3.0-Liter Turbodiesel V6
# 24              3.0-Liter Flat-Six
# 25  Twin-Turbocharged 3.0-Liter V6

# %%
df.dtypes
# Out:
# Unnamed: 0         int64
# year               int64
# make              object
# model             object
# final_price       object
# mileage            int64
# engine            object
# zipcode            int64
# car_fax_report    object
# engine string     object
# dtype: object

# %%
for i in range(7624):
    value = df.iloc[i, 6]
    if type(value) == str:
        df.iloc[i, 6] = 0
# Out:
# C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['engine'] = df['engine'].astype(float)
# Out:
# C:\Users\austi\AppData\Local\Temp/ipykernel_15492/2176177890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['engine'] = df['engine'].astype(float)

# %%
df = df.query('engine != 0')
df
# Out:
#       Unnamed: 0  year           make                       model final_price  \
# 0              0  1999        Porsche             Porsche 996 911     $29,840
# 1              1  1976        Triumph                 Triumph TR6     $23,500
# 2              2  2015      Chevrolet       Chevrolet Corvette C7     $87,000
# 5              5  1994            BMW            BMW E31 8-Series     $19,900
# 6              6  2020           Jeep               Jeep Wrangler     $65,000
# ...          ...   ...            ...                         ...         ...
# 9946        9946  2013  Mercedes-Benz       Mercedes-Benz R231 SL    $120,000
# 9947        9947  2005  Mercedes-Benz  Mercedes-Benz W220 S-Class     $29,750
# 9948        9948  1974          Honda           Honda Motorcycles      $3,500
# 9949        9949  1987            BMW            BMW E30 3-Series     $15,750
# 9951        9951  1987        Porsche           Porsche 930 Turbo     $84,000
#
#       mileage  engine  zipcode car_fax_report                    engine string
# 0       44000  3400.0    33407      No Carfax               3.4-Liter Flat-Six
# 1       95000  2500.0    46229      No Carfax             2.5-Liter Inline-Six
# 2      410000  6200.0    45429         Carfax        Supercharged 6.2-Liter V8
# 5       95000  4000.0    92887         Carfax                     4.0-Liter V8
# 6       17000  6400.0    48507         Carfax                     6.4-Liter V8
# ...       ...     ...      ...            ...                              ...
# 9946    11000  6000.0    33067         Carfax  Twin-Turbocharged 6.0-Liter V12
# 9947    40000  5400.0    53114         Carfax       Supercharged 5.4-Liter V8
# 9948     3000    89.0    95032      No Carfax          89cc Four-Stroke Single
# 9949    48000  2500.0    35223         Carfax         2.5-Liter M20 Inline-Six
# 9951    42000  3300.0    92201      No Carfax  Turbocharged 3.3-Liter Flat-Six
#
# [7366 rows x 10 columns]

# %%
df = df.query('mileage < 300000')
df
# Out:
#       Unnamed: 0  year           make                       model final_price  \
# 0              0  1999        Porsche             Porsche 996 911     $29,840
# 1              1  1976        Triumph                 Triumph TR6     $23,500
# 5              5  1994            BMW            BMW E31 8-Series     $19,900
# 6              6  2020           Jeep               Jeep Wrangler     $65,000
# 7              7  1966           Ford    Ford Mustang 1964.5-1966     $35,750
# ...          ...   ...            ...                         ...         ...
# 9946        9946  2013  Mercedes-Benz       Mercedes-Benz R231 SL    $120,000
# 9947        9947  2005  Mercedes-Benz  Mercedes-Benz W220 S-Class     $29,750
# 9948        9948  1974          Honda           Honda Motorcycles      $3,500
# 9949        9949  1987            BMW            BMW E30 3-Series     $15,750
# 9951        9951  1987        Porsche           Porsche 930 Turbo     $84,000
#
#       mileage    engine  zipcode car_fax_report  \
# 0       44000  3400.000    33407      No Carfax
# 1       95000  2500.000    46229      No Carfax
# 5       95000  4000.000    92887         Carfax
# 6       17000  6400.000    48507         Carfax
# 7       31000  4735.843    97005      No Carfax
# ...       ...       ...      ...            ...
# 9946    11000  6000.000    33067         Carfax
# 9947    40000  5400.000    53114         Carfax
# 9948     3000    89.000    95032      No Carfax
# 9949    48000  2500.000    35223         Carfax
# 9951    42000  3300.000    92201      No Carfax
#
#                         engine string
# 0                  3.4-Liter Flat-Six
# 1                2.5-Liter Inline-Six
# 5                        4.0-Liter V8
# 6                        6.4-Liter V8
# 7                            289ci V8
# ...                               ...
# 9946  Twin-Turbocharged 6.0-Liter V12
# 9947       Supercharged 5.4-Liter V8
# 9948          89cc Four-Stroke Single
# 9949         2.5-Liter M20 Inline-Six
# 9951  Turbocharged 3.3-Liter Flat-Six
#
# [7108 rows x 10 columns]

# %%
df.to_csv('final_dataset_acc.csv')

# %%
import sqlite3
conn = sqlite3.connect('data.sqlite')
df.to_sql('new_table_name', conn, if_exists='replace', index=False)
# Out:
# C:\Users\austi\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(
