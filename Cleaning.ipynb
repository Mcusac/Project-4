# %%
import pandas as pd

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#       Unnamed: 0  year        make                                      model  \
# 0              0  1993  Land Rover  Land Rover 110 / Defender 110 (Euro Spec)
# 1              1  1997   Chevrolet                         Chevrolet Suburban
# 2              2  1990     Porsche                            Porsche 964 911
# 3              3  2003      Toyota                              Toyota Pickup
# 4              4  1971     Triumph                                Triumph TR6
# ...          ...   ...         ...                                        ...
# 1914        1914  2009     Porsche                            Porsche 997 911
# 1915        1915  2001      Toyota                              Toyota Pickup
# 1916        1916  1991   Chevrolet  Chevrolet Camaro 3rd Generation 1982-1992
# 1917        1917  1969  Oldsmobile                           Oldsmobile 4-4-2
# 1918        1918  1969      Shelby                       Shelby Cobra Replica
#
# ...

# %%
df = df.query('mileage != 0')
df
# Out:
#       Unnamed: 0  year        make                                      model  \
# 1              1  1997   Chevrolet                         Chevrolet Suburban
# 2              2  1990     Porsche                            Porsche 964 911
# 3              3  2003      Toyota                              Toyota Pickup
# 5              5  1992  Volkswagen           Volkswagen Golf/Rabbit Cabriolet
# 6              6  2008      Toyota                          Toyota FJ Cruiser
# ...          ...   ...         ...                                        ...
# 1913        1913  2011         BMW                         BMW E90/E92/E93 M3
# 1914        1914  2009     Porsche                            Porsche 997 911
# 1915        1915  2001      Toyota                              Toyota Pickup
# 1916        1916  1991   Chevrolet  Chevrolet Camaro 3rd Generation 1982-1992
# 1917        1917  1969  Oldsmobile                           Oldsmobile 4-4-2
#
# ...

# %%
df.to_csv('final_dataset.csv')
